# %% [markdown]
# <a href="https://colab.research.google.com/github/kaviya-suresh-1/24ADI003-24BAD059-EXP-2-/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
v
